# %%
import pandas as pd
df=pd.read_csv('Job_Application_Filings.csv')
print(df.shape)

df_subset=df[0:1000]
# Out:
# C:\Users\Antonio\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5,6,13,14,20,21,32,38,59,60,68,78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1614199, 96)

# %%
# Print the head of df
#print(df_subset.head())

# Print the tail of df
#print(df_subset.tail())


print(df_subset.shape) #this tells me how many rows and columns


print(df_subset.columns) # Print the columns of df
# Out:
# (1000, 96)
# Index(['Job #', 'Doc #', 'Borough', 'House #', 'Street Name', 'Block', 'Lot',
#        'Bin #', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'Community - Board', 'Cluster',
#        'Landmarked', 'Adult Estab', 'Loft Board', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Plumbing', 'Mechanical', 'Boiler',
#        'Fuel Burning', 'Fuel Storage', 'Standpipe', 'Sprinkler', 'Fire Alarm',
#        'Equipment', 'Fire Suppression', 'Curb Cut', 'Other',
#        'Other Description', 'Applicant's First Name', 'Applicant's Last Name',
#        'Applicant Professional Title', 'Applicant License #',
#        'Professional Cert', 'Pre- Filing Date', 'Paid', 'Fully Paid',
#        'Assigned', 'Approved', 'Fully Permitted', 'Initial Cost',
#        'Total Est. Fee', 'Fee Status', 'Existing Zoning Sqft',
#        'Proposed Zoning Sqft', 'Horizontal Enlrgmt', 'Vertical Enlrgmt',
# ...

# %%
print(df_subset.info()) #this tells me inforamtion about each column
#notice: Initial Fee est is object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 96 columns):
# Job #                            1000 non-null int64
# Doc #                            1000 non-null int64
# Borough                          1000 non-null object
# House #                          1000 non-null object
# Street Name                      1000 non-null object
# Block                            1000 non-null object
# Lot                              1000 non-null object
# Bin #                            1000 non-null int64
# Job Type                         1000 non-null object
# Job Status                       1000 non-null object
# Job Status Descrp                1000 non-null object
# Latest Action Date               1000 non-null object
# Building Type                    1000 non-null object
# Community - Board                1000 non-null object
# Cluster                          981 non-null object
# ...

# %%
df_subset['City '].value_counts(dropna=False) #this is a frequency count and gives me a tally of each value in the column (uncluding NaB)
df_subset['City '].value_counts(dropna=False).head() #we can also apply more methods to this
# Out:
# NEW YORK         349
# BROOKLYN         241
# QUEENS            73
# STATEN ISLAND     42
# BRONX             33
# Name: City , dtype: int64

# %%
# Print the value counts for 'Borough'
print(df_subset['Borough'].value_counts(dropna=False).head())

# Print the value_counts for 'State'
print(df_subset['State'].value_counts(dropna=False).head())

# Print the value counts for 'Site Fill'
print(df_subset['Initial Cost'].value_counts(dropna=False).head())
# Out:
# MANHATTAN        359
# BROOKLYN         350
# QUEENS           172
# BRONX             68
# STATEN ISLAND     51
# Name: Borough, dtype: int64
# NY    968
# NJ     20
# TN      3
# MA      2
# CA      2
# Name: State, dtype: int64
# $0.00        269
# $1000.00      27
# $10000.00     23
# $30000.00     16
# $50000.00     13
# Name: Initial Cost, dtype: int64

# %% [markdown]
# **Summary Statistics**

# %%
df_subset.describe()
# Out:
#               Job #        Doc #         Bin #  Existing Zoning Sqft  \
# count  1.000000e+03  1000.000000  1.000000e+03          1.000000e+03
# mean   2.735234e+08     1.259000  2.623829e+06          7.529059e+03
# std    1.277421e+08     0.767142  1.344890e+06          9.816348e+04
# min    1.029432e+08     1.000000  1.000059e+06          0.000000e+00
# 25%    1.233844e+08     1.000000  1.077376e+06          0.000000e+00
# 50%    3.211901e+08     1.000000  3.032168e+06          0.000000e+00
# 75%    3.405086e+08     1.000000  3.425681e+06          0.000000e+00
# max    5.401545e+08     7.000000  5.171139e+06          2.727300e+06
#
#        Proposed Zoning Sqft  Enlargement SQ Footage  Street Frontage  \
# count          1.000000e+03             1000.000000      1000.000000
# mean           1.475822e+04              173.640000         3.538000
# std            1.282714e+05             1377.439601        37.913031
# ...

# %% [markdown]
# **Bar plots and histograms**
#
# Bar plots for discrete data counts
#
# Histogram for continuous data
#
# Scatter plots for multiple variables

# %%
import matplotlib.pyplot as plt

df_subset['Existing Zoning Sqft'].plot(kind='hist', rot=70, logx=True, logy=True)
plt.show()

# %%
df.boxplot(column='Existing Height',by='Borough',rot=90) #this shows a boxplit of initial cost and seperates it by borough(different rows)
plt.show()

# %%
df_subset.plot(kind='scatter',x='Existing Height', y='Proposed Height',  rot=70)
plt.show()
