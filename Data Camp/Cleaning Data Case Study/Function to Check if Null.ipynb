# %%
import pandas as pd
g1800s=pd.read_csv('g1800s.csv',encoding='latin-1', index_col= 0)

# %%
def check_null_or_valid(row_data):
    """Function that takes a row of data,
    drops all missing values,
    and checks if all remaining values are greater than or equal to 0
    """
    no_na = row_data.dropna()[1:-1]
    
    numeric = pd.to_numeric(no_na)
    ge0 = numeric >= 0
    return ge0

# Check whether the first column is 'Life expectancy'
assert g1800s.columns[0] == 'Life expectancy'

#Check whether the values in the row are valid
assert g1800s.iloc[:, 1:].apply(check_null_or_valid, axis=1).all().all()

#Check that there is only one instance of each country
#assert g1800s['Life expectancy'].value_counts()[0] == 1
g1800s.dropna(how='any')
g1800s['Life expectancy'].value_counts()
# Out:
# Martinique                  3
# Svalbard                    3
# Seychelles                  3
# Uganda                      3
# New Zealand                 3
# Ethiopia                    3
# Serbia and Montenegro       3
# Botswana                    3
# Angola                      3
# Serbia excluding Kosovo     3
# Guam                        3
# Turkmenistan                3
# Morocco                     3
# Guyana                      3
# Central African Republic    3
# East Germany                3
# South Africa                3
# St. Lucia                   3
# Uruguay                     3
# Nepal                       3
# Mali                        3
# Croatia                     3
# Greece                      3
# Libya                       3
# United States               3
# Hungary                     3
# Ngorno-Karabakh             3
# Tanzania                    3
# Pitcairn                    3
# Benin                       3
#                            ..
# ...

# %%
def drop_rows_contain_na(row_data):
    """Function that takes a row of data,
    drops all missing values
    """
    no_na = row_data.dropna(how='all')
    
    return numeric
df=g1800s.iloc[:,1:].apply(drop_rows_contain_na, axis=1)
df
# Out:
#       1800   1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14  28.13  28.12
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4    28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# 5      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7    26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# 8      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9    33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54
# 10   33.20  33.20  33.20  33.20  33.20  33.20  33.20  33.20  33.20  33.20
# 11   34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00
# ...
